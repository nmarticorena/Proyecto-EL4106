# %%
from sympy import *
from sympy.physics.vector import dynamicsymbols, vlatex
from sympy.physics.mechanics import *
import matplotlib.pyplot as plt

# %%
t1=dynamicsymbols('theta_2')
t2=dynamicsymbols('theta_3')
t3=dynamicsymbols('theta_4')
t=Symbol("t")
dt1=dynamicsymbols('theta_2',1)
dt2=dynamicsymbols('theta_3',1)
dt3=dynamicsymbols('theta_4',1)
M=Symbol("M")
L=Symbol("l")
g=Symbol("g")

# %% [markdown]
# ## K1 y P1

# %%
K1=(1./2.)*M*L**2*dt1**2
P1=M*g*L*cos(t1)
init_printing()

# %%
print(vlatex(K1))
print(vlatex(P1))
# Out:
# 0.5 M l^{2} \dot{\theta}_{2}^{2}
# M g l \operatorname{cos}\left(\theta_{2}\right)

# %% [markdown]
# ## K2 y P2

# %%
x2=L*sin(t1)+L*sin(t1+t2)
z2=L*cos(t1)+L*cos(t1+t2)
v2=(diff(x2,Symbol("t")))**2+(diff(z2,Symbol("t")))**2
v2=simplify(v2)
v2

plt.plot()
plt.text(0, 0,'$x_2=%s$'%vlatex(x2),size=100)
plt.axis('off')
plt.show()

plt.plot()
plt.text(0, 0,'$z_2=%s$'%vlatex(z2),size=100)
plt.axis('off')
plt.show()

plt.plot()
plt.text(0, 0,'$V_2=%s$'%vlatex(v2),size=100)
plt.axis('off')
plt.show()

# %%
print(vlatex(x2))
print(vlatex(z2))
print(vlatex(v2))
# Out:
# l \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{sin}\left(\theta_{2}\right)
# l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{cos}\left(\theta_{2}\right)
# l^{2} \left(2 \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} + 2 \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 2 \dot{\theta}_{2}^{2} + 2 \dot{\theta}_{2} \dot{\theta}_{3} + \dot{\theta}_{3}^{2}\right)

# %%
K2=(1./2.)*M*v2
P2=M*g*z2

# %%
plt.plot()
plt.text(0, 0,'$K_2=%s$'%vlatex(K2),size=100)
plt.axis('off')
plt.show()

plt.plot()
plt.text(0, 0,'$P_2=%s$'%vlatex(P2),size=100)
plt.axis('off')
plt.show()

# %%
print(vlatex(K2))
print(vlatex(P2))
# Out:
# 0.5 M l^{2} \left(2 \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} + 2 \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 2 \dot{\theta}_{2}^{2} + 2 \dot{\theta}_{2} \dot{\theta}_{3} + \dot{\theta}_{3}^{2}\right)
# M g \left(l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{cos}\left(\theta_{2}\right)\right)

# %% [markdown]
# ## K3 y P3

# %%
x3=L*sin(t1)+L*sin(t1+t2)+L*sin(t1+t2+t3)
z3=L*cos(t1)+L*cos(t1+t2)+L*cos(t1+t2+t3)
v3=(diff(x3,Symbol("t")))**2+(diff(z3,Symbol("t")))**2
v3
v3
# Out:
#
# ⎛    ⎛d           d        ⎞                        ⎛d           d           d
# ⎜- l⋅⎜──(θ₂(t)) + ──(θ₃(t))⎟⋅sin(θ₂(t) + θ₃(t)) - l⋅⎜──(θ₂(t)) + ──(θ₃(t)) + ─
# ⎝    ⎝dt          dt       ⎠                        ⎝dt          dt          d
#
#                                                               2
#         ⎞                                           d        ⎞    ⎛  ⎛d
# ─(θ₄(t))⎟⋅sin(θ₂(t) + θ₃(t) + θ₄(t)) - l⋅sin(θ₂(t))⋅──(θ₂(t))⎟  + ⎜l⋅⎜──(θ₂(t)
# t       ⎠                                           dt       ⎠    ⎝  ⎝dt
#
#
#     d        ⎞                        ⎛d           d           d        ⎞
# ) + ──(θ₃(t))⎟⋅cos(θ₂(t) + θ₃(t)) + l⋅⎜──(θ₂(t)) + ──(θ₃(t)) + ──(θ₄(t))⎟⋅cos(
#     dt       ⎠                        ⎝dt          dt          dt       ⎠
#
#                                                 2
#                                       d        ⎞
# θ₂(t) + θ₃(t) + θ₄(t)) + l⋅cos(θ₂(t))⋅──(θ₂(t))⎟
#                                       dt       ⎠

# %%
print(vlatex(x3))
print(vlatex(z3))
# Out:
# l \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + l \operatorname{sin}\left(\theta_{2}\right)
# l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + l \operatorname{cos}\left(\theta_{2}\right)

# %%
print(vlatex(simplify(v3)))
# Out:
# l^{2} \left(\left(\left(\dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) + \left(\dot{\theta}_{2} + \dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + \operatorname{sin}\left(\theta_{2}\right) \dot{\theta}_{2}\right)^{2} + \left(\left(\dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + \left(\dot{\theta}_{2} + \dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + \operatorname{cos}\left(\theta_{2}\right) \dot{\theta}_{2}\right)^{2}\right)

# %%
K3=(1./2.)*M*v3
P3=M*g*z3
print(vlatex(K3))
print(vlatex(P3))
# Out:
# 0.5 M \left(\left(- l \left(\dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) - l \left(\dot{\theta}_{2} + \dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) - l \operatorname{sin}\left(\theta_{2}\right) \dot{\theta}_{2}\right)^{2} + \left(l \left(\dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + l \left(\dot{\theta}_{2} + \dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + l \operatorname{cos}\left(\theta_{2}\right) \dot{\theta}_{2}\right)^{2}\right)
# M g \left(l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) + l \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + l \operatorname{cos}\left(\theta_{2}\right)\right)

# %%
plt.plot()
plt.text(0, 0,'$P_3=%s$'%vlatex(P3),size=100)
plt.axis('off')
plt.show()

# %% [markdown]
# $K3= 0.5 L^{2} M \left(\left(\left(\dot{\theta}_{1} + \dot{\theta}_{2}\right) \operatorname{sin}\left(\theta_{1} + \theta_{2}\right) + \left(\dot{\theta}_{1} + \dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{sin}\left(\theta_{1} + \theta_{2} + \theta_{3}\right) + \operatorname{sin}\left(\theta_{1}\right) \dot{\theta}_{1}\right)^{2} + \left(\left(\dot{\theta}_{1} + \dot{\theta}_{2}\right) \operatorname{cos}\left(\theta_{1} + \theta_{2}\right) + \left(\dot{\theta}_{1} + \dot{\theta}_{2} + \dot{\theta}_{3}\right) \operatorname{cos}\left(\theta_{1} + \theta_{2} + \theta_{3}\right) + \operatorname{cos}\left(\theta_{1}\right) \dot{\theta}_{1}\right)^{2}\right)$

# %% [markdown]
# # Lagrangiano

# %%
L=K1+K2+K3-P1-P2-P3
L=simplify(L)
print(vlatex(L))
L
# Out:
# M l \left(- 2.0 g \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) - 1.0 g \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) - 3.0 g \operatorname{cos}\left(\theta_{2}\right) + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2}^{2} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{3}^{2} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\
# ...

# %% [markdown]
# $ M l \left(- 2.0 g \operatorname{cos}\left(\theta_{1} + \theta_{2}\right) - 1.0 g \operatorname{cos}\left(\theta_{1} + \theta_{2} + \theta_{3}\right) - 3.0 g \operatorname{cos}\left(\theta_{1}\right) + 1.0 l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) \dot{\theta}_{1}^{2} + 1.0 l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) \dot{\theta}_{1} \dot{\theta}_{2} + 1.0 l \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) \dot{\theta}_{1} \dot{\theta}_{3} + 2.0 l \operatorname{cos}\left(\theta_{2}\right) \dot{\theta}_{1}^{2} + 2.0 l \operatorname{cos}\left(\theta_{2}\right) \dot{\theta}_{1} \dot{\theta}_{2} + 1.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{1}^{2} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{1} \dot{\theta}_{2} + 1.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{1} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} + 1.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 3.0 l \dot{\theta}_{1}^{2} + 3.0 l \dot{\theta}_{1} \dot{\theta}_{2} + 1.0 l \dot{\theta}_{1} \dot{\theta}_{3} + 1.5 l \dot{\theta}_{2}^{2} + 1.0 l \dot{\theta}_{2} \dot{\theta}_{3} + 0.5 l \dot{\theta}_{3}^{2}\right)
#  $

# %% [markdown]
# $L=M l \left(- 2.0 g \operatorname{cos}\left(\theta_{2} + \theta_{3}\right) - 1.0 g \operatorname{cos}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) - 3.0 g \operatorname{cos}\left(\theta_{2}\right) + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2}^{2} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{3}^{2} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \dot{\theta}_{3} \dot{\theta}_{4} + 3.0 l \dot{\theta}_{2}^{2} + 3.0 l \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \dot{\theta}_{2} \dot{\theta}_{4} + 1.5 l \dot{\theta}_{3}^{2} + 1.0 l \dot{\theta}_{3} \dot{\theta}_{4} + 0.5 l \dot{\theta}_{4}^{2}\right)
# $

# %%
torque1=diff(diff(L,dt1),t)-diff(L,t1)
torque2=diff(diff(L,dt2),t)-diff(L,t2)
torque3=diff(diff(L,dt3),t)-diff(L,t3)

torque1=simplify(torque1)
torque2=simplify(torque2)
torque3=simplify(torque3)

# %% [markdown]
# $\tau_1=M l \left(- g \left(2.0 \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) + 1.0 \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + 3.0 \operatorname{sin}\left(\theta_{2}\right)\right) + l \left(- 2.0 \left(\dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{sin}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2} - 1.0 \left(\dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{sin}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{3} - 1.0 \left(\dot{\theta}_{3} + \dot{\theta}_{4}\right) \operatorname{sin}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{4} - 4.0 \operatorname{sin}\left(\theta_{3}\right) \dot{\theta}_{2} \dot{\theta}_{3} - 2.0 \operatorname{sin}\left(\theta_{3}\right) \dot{\theta}_{3}^{2} - 2.0 \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} - 2.0 \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{3} \dot{\theta}_{4} - 1.0 \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{4}^{2} + 2.0 \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \ddot{\theta}_{2} + 1.0 \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \ddot{\theta}_{3} + 1.0 \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \ddot{\theta}_{4} + 4.0 \operatorname{cos}\left(\theta_{3}\right) \ddot{\theta}_{2} + 2.0 \operatorname{cos}\left(\theta_{3}\right) \ddot{\theta}_{3} + 2.0 \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{2} + 2.0 \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{3} + 1.0 \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{4} + 6.0 \ddot{\theta}_{2} + 3.0 \ddot{\theta}_{3} + 1.0 \ddot{\theta}_{4}\right)\right)$
#
# $ \tau_2=M l \left(- 2.0 g \operatorname{sin}\left(\theta_{2} + \theta_{3}\right) - 1.0 g \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + 1.0 l \operatorname{sin}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{sin}\left(\theta_{3}\right) \dot{\theta}_{2}^{2} - 2.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{4} - 2.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{3} \dot{\theta}_{4} - 1.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{4}^{2} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \ddot{\theta}_{2} + 2.0 l \operatorname{cos}\left(\theta_{3}\right) \ddot{\theta}_{2} + 2.0 l \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{2} + 2.0 l \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{3} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{4} + 3.0 l \ddot{\theta}_{2} + 3.0 l \ddot{\theta}_{3} + 1.0 l \ddot{\theta}_{4}\right)$
#
# $ \tau_3=M l \left(- 1.0 g \operatorname{sin}\left(\theta_{2} + \theta_{3} + \theta_{4}\right) + 1.0 l \operatorname{sin}\left(\theta_{3} + \theta_{4}\right) \dot{\theta}_{2}^{2} + 1.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{2}^{2} + 2.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{2} \dot{\theta}_{3} + 1.0 l \operatorname{sin}\left(\theta_{4}\right) \dot{\theta}_{3}^{2} + 1.0 l \operatorname{cos}\left(\theta_{3} + \theta_{4}\right) \ddot{\theta}_{2} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{2} + 1.0 l \operatorname{cos}\left(\theta_{4}\right) \ddot{\theta}_{3} + 1.0 l \ddot{\theta}_{2} + 1.0 l \ddot{\theta}_{3} + 1.0 l \ddot{\theta}_{4}\right)$
